# %% [markdown]
# ## Prepare Env

# %%
# !python -m venv venv
# !source venv/bin/activate

# %%
# %pip install boto3 pyspark delta-spark python-dotenv
# Out:
# Collecting boto3
#   Downloading boto3-1.34.20-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyspark
#   Downloading pyspark-3.5.0.tar.gz (316.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 758.9 kB/s eta 0:00:0000:0100:11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting delta-spark
#   Downloading delta_spark-3.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting botocore<1.35.0,>=1.34.20 (from boto3)
#   Downloading botocore-1.34.20-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting py4j==0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 269.5 kB/s eta 0:00:00a 0:00:01
# Collecting importlib-metadata>=1.0.0 (from delta-spark)
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/quangtu/Documents/Codes/icttm/adam_datalake/.venv/lib/python3.12/site-packages (from botocore<1.35.0,>=1.34.20->boto3) (2.8.2)
# Collecting urllib3<2.1,>=1.25.4 (from botocore<1.35.0,>=1.34.20->boto3)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=1.0.0->delta-spark)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: six>=1.5 in /Users/quangtu/Documents/Codes/icttm/adam_datalake/.venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.20->boto3) (1.16.0)
# Downloading boto3-1.34.20-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 238.8 kB/s eta 0:00:00a 0:00:01
# Downloading delta_spark-3.0.0-py3-none-any.whl (21 kB)
# Downloading botocore-1.34.20-py3-none-any.whl (11.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 554.6 kB/s eta 0:00:0000:0100:01
# Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 804.0 kB/s eta 0:00:00a 0:00:01
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 741.7 kB/s eta 0:00:00a 0:00:01
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425345 sha256=2e5f5bf5d46b0c9bb54a05b8100bd25893f406bfe494b9d59a2cf802fad0df7d
#   Stored in directory: /Users/quangtu/Library/Caches/pip/wheels/84/40/20/65eefe766118e0a8f8e385cc3ed6e9eb7241c7e51cfc04c51a
# Successfully built pyspark
# Installing collected packages: py4j, zipp, urllib3, python-dotenv, pyspark, jmespath, importlib-metadata, botocore, s3transfer, delta-spark, boto3
# Successfully installed boto3-1.34.20 botocore-1.34.20 delta-spark-3.0.0 importlib-metadata-7.0.1 jmespath-1.0.1 py4j-0.10.9.7 pyspark-3.5.0 python-dotenv-1.0.0 s3transfer-0.10.0 urllib3-2.0.7 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
# Define S3 storage
obj_storage_access_key = os.getenv('OBJ_STORAGE_ACCESS_KEY', 'demo-access-key')
obj_storage_secret_key = os.getenv('OBJ_STORAGE_SECRET_KEY', 'demo-secret-key')
obj_storage_endpoint = os.getenv('OBJ_STORAGE_ENDPOINT', 'http://localhost:9000')

# %% [markdown]
# ## Ingestion
# ### 1. Layer files to layer bronze
# Write files which are in layer files to delta table in layer bronze

# %%
# Create a Spark session
spark = SparkSession.builder \
    .appName("CsvToDelta") \
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.0.0,org.apache.hadoop:hadoop-aws:3.3.1") \
    .config("spark.hadoop.fs.s3a.endpoint", obj_storage_endpoint) \
    .config("spark.hadoop.fs.s3a.access.key", obj_storage_access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", obj_storage_secret_key) \
    .config('spark.hadoop.fs.s3a.path.style.access', "true") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()
# Out:
# 24/01/17 14:50:12 WARN Utils: Your hostname, Lukes-Macbook.local resolves to a loopback address: 127.0.0.1; using 192.168.1.18 instead (on interface en0)
# 24/01/17 14:50:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/quangtu/.ivy2/cache
# The jars for the packages stored in: /Users/quangtu/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-e50bfeab-4f21-4a3b-a192-4b2961f064f1;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/Users/quangtu/Documents/Codes/icttm/adam_datalake/.venv/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.apache.hadoop#hadoop-aws;3.3.1 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.901 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-bundle/1.11.901/aws-java-sdk-bundle-1.11.901.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-bundle;1.11.901!aws-java-sdk-bundle.jar (1357635ms)
# downloading https://repo1.maven.org/maven2/org/wildfly/openssl/wildfly-openssl/1.0.7.Final/wildfly-openssl-1.0.7.Final.jar ...
# 	[SUCCESSFUL ] org.wildfly.openssl#wildfly-openssl;1.0.7.Final!wildfly-openssl.jar (4620ms)
# :: resolution report :: resolve 146ms :: artifacts dl 1362267ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.901 from central in [default]
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.1 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   6   |   0   |   0   |   0   ||   6   |   2   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-e50bfeab-4f21-4a3b-a192-4b2961f064f1
# 	confs: [default]
# 	6 artifacts copied, 0 already retrieved (194308kB/202ms)
# 24/01/17 15:12:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/01/17 15:13:06 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# :: resolution report :: resolve 16669ms :: artifacts dl 1547064ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.901 from central in [default]
# 	io.delta#delta-spark_2.12;3.0.0 from central in [default]
# 	io.delta#delta-storage;3.0.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.1 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   6   |   6   |   6   |   0   ||   6   |   4   |
# 	---------------------------------------------------------------------
#
# :: problems summary ::
# :::: WARNINGS
# 		[FAILED     ] com.amazonaws#aws-java-sdk-bundle;1.11.901!aws-java-sdk-bundle.jar: Downloaded file size (0) doesn't match expected Content Length (192321266) for https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-bundle/1.11.901/aws-java-sdk-bundle-1.11.901.jar. Please retry. (1481905ms)
#
# 		[FAILED     ] com.amazonaws#aws-java-sdk-bundle;1.11.901!aws-java-sdk-bundle.jar: Downloaded file size (0) doesn't match expected Content Length (192321266) for https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-bundle/1.11.901/aws-java-sdk-bundle-1.11.901.jar. Please retry. (1481905ms)
#
# 	==== central: tried
#
# 	  https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-bundle/1.11.901/aws-java-sdk-bundle-1.11.901.jar
#
# 		::::::::::::::::::::::::::::::::::::::::::::::
#
# 		::              FAILED DOWNLOADS            ::
#
# 		:: ^ see resolution messages for details  ^ ::
#
# 		::::::::::::::::::::::::::::::::::::::::::::::
#
# 		:: com.amazonaws#aws-java-sdk-bundle;1.11.901!aws-java-sdk-bundle.jar
#
# 		::::::::::::::::::::::::::::::::::::::::::::::
#
#
#
# :: USE VERBOSE OR DEBUG MESSAGE LEVEL FOR MORE DETAILS
# Exception in thread "main" java.lang.RuntimeException: [download failed: com.amazonaws#aws-java-sdk-bundle;1.11.901!aws-java-sdk-bundle.jar]
# 	at org.apache.spark.deploy.SparkSubmitUtils$.resolveMavenCoordinates(SparkSubmit.scala:1537)
# 	at org.apache.spark.util.DependencyUtils$.resolveMavenDependencies(DependencyUtils.scala:185)
# 	at org.apache.spark.deploy.SparkSubmit.prepareSubmitEnvironment(SparkSubmit.scala:334)
# 	at org.apache.spark.deploy.SparkSubmit.org$apache$spark$deploy$SparkSubmit$$runMain(SparkSubmit.scala:964)
# 	at org.apache.spark.deploy.SparkSubmit.doRunMain$1(SparkSubmit.scala:194)
# 	at org.apache.spark.deploy.SparkSubmit.submit(SparkSubmit.scala:217)
# 	at org.apache.spark.deploy.SparkSubmit.doSubmit(SparkSubmit.scala:91)
# 	at org.apache.spark.deploy.SparkSubmit$$anon$2.doSubmit(SparkSubmit.scala:1120)
# 	at org.apache.spark.deploy.SparkSubmit$.main(SparkSubmit.scala:1129)
# 	at org.apache.spark.deploy.SparkSubmit.main(SparkSubmit.scala)

# %%
file_path = "s3a://warehouse/files/latvia.file/data.csv"
delta_table_path = "s3a://warehouse/bronze/latvia_entities.delta"

# %%
# Read file into a DataFrame
df = spark.read.csv(file_path, header=True, sep=";")

# %%
df.show()
# Out:
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# |    regcode|              sepa|                name|  name_before_quotes|      name_in_quotes|name_after_quotes|without_quotes|regtype|        regtype_text|type|           type_text|registered|terminated|closed|             address|index|addressid|   region|     city|   atvk|reregistration_term|
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# |41202013815|LV53ZZZ41202013815|"IK ""KRASTNIEKI ...|                  IK|      KRASTNIEKI A I|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|1998-02-26|2014-04-10|     L|"Dundagas nov., K...| 3275|103045133|100015821|        0|0885162|               NULL|
# |41502039688|LV14ZZZ41502039688|"IK ""MasterClean"""|                  IK|         MasterClean|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|2020-03-03|      NULL|      |Augšdaugavas nov....| 5451|115740415|100016462|        0|0440274|               NULL|
# |40008048734|LV28ZZZ40008048734|"Mednieku klubs "...|      Mednieku klubs|             Atpūtas|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2000-02-23|      NULL|      |Rīga, Zemes iela ...| 1082|115058568|        0|100003003|0010000|               NULL|
# |40002158072|LV09ZZZ40002158072|           IK DANDIS|                  IK|              DANDIS|             NULL|             1|      K|      Komercreģistrs|  IK|Individuālais kom...|2010-11-24|2014-04-09|     L|"Babītes nov., Ba...| 2107|103045920|100015725|        0|0804948|               NULL|
# |40002102524|LV88ZZZ40002102524|     "IK ""Dīfija"""|                  IK|              Dīfija|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|2004-04-02|2014-04-09|     L| Rīga, Avotu iela 17| 1011|101858996|        0|100003003|0010000|               NULL|
# |41502039692|LV03ZZZ41502039692|     "IK ""D.Luxe"""|                  IK|              D.Luxe|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|2020-03-05|      NULL|      |Daugavpils, Aroni...| 5414|105057694|        0|100003011|0050000|               NULL|
# |40008229769|LV10ZZZ40008229769|"""IEDVESMU PĻAVA"""|                NULL|      IEDVESMU PĻAVA|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2014-10-28|      NULL|      |Rīga, Apes iela 5...| 1039|117983582|        0|100003003|0010000|               NULL|
# |50002172701|LV45ZZZ50002172701|         IK EUROKONT|                  IK|            EUROKONT|             NULL|             1|      K|      Komercreģistrs|  IK|Individuālais kom...|2014-09-30|      NULL|      |Rīga, Neretas iel...| 1004|118038565|        0|100003003|0010000|               NULL|
# |40008228763|LV12ZZZ40008228763|"""MĀJAS APSAIMNI...|                NULL|MĀJAS APSAIMNIEKO...|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2014-10-07|      NULL|      |Jelgavas nov., Ce...| 3042|115524146|100016534|        0|0546744|               NULL|
# |40003868290|              NULL|"Sabiedrība ar ie...|Sabiedrība ar ier...|            AST BŪVE|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2006-10-24|2013-12-11|     L|Jūrmala, Raiņa ie...| 2011|116484351|        0|100003036|0130000|               NULL|
# |41502039796|LV08ZZZ41502039796| "IK ""POWER TEST"""|                  IK|          POWER TEST|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|2020-06-30|      NULL|      |Augšdaugavas nov....| 5481|116960711|100016462|        0|0440298|               NULL|
# |40103215608|              NULL|   "SIA ""Baltima"""|                 SIA|             Baltima|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2009-02-17|2013-12-11|     L|Rīga, Trijādības ...| 1048|102009175|        0|100003003|0010000|               NULL|
# |40203246549|LV84ZZZ40203246549|  "SIA ""ES Trade"""|                 SIA|            ES Trade|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2020-05-11|2023-08-15|     L|Ropažu nov., Stop...| 2130|105671714|100016784|        0|0809600|               NULL|
# |41502039809|LV45ZZZ41502039809|          MedveDJ IK|                NULL|             MedveDJ|               IK|             1|      K|      Komercreģistrs|  IK|Individuālais kom...|2020-07-03|      NULL|      |Daugavpils, Saule...| 5401|116123047|        0|100003011|0050000|               NULL|
# |44101017469|LV12ZZZ44101017469|"Cēsu rajona Drab...|Cēsu rajona Drabe...|            VECLAUČI|             NULL|             0|      U|Uzņēmumu reģistra...| ZEM|Zemnieku saimniecība|1994-11-25|2017-04-12|     L|"Amatas nov., Dra...| 4139|104236640|100015276|        0|0424746|               NULL|
# |40002161528|              NULL|"IK ""SAULES ROTA...|                  IK|        SAULES ROTAS|             NULL|             0|      K|      Komercreģistrs|  IK|Individuālais kom...|2011-07-07|2013-12-11|     L|Ķekavas nov., Ķek...| 2111|104895553|100015950|        0|0800870|               NULL|
# |40003470770|              NULL|  "SIA ""KRIPTO K"""|                 SIA|            KRIPTO K|             NULL|             0|      U|Uzņēmumu reģistra...| SIA|Sabiedrība ar ier...|1999-12-01|2003-12-17|     L|Rīga, Rododendru ...| 1083|113974575|        0|100003003|0010000|               NULL|
# |40003766227|              NULL|   "SIA ""KATTEKS"""|                 SIA|             KATTEKS|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2005-09-06|2013-12-12|     L|Rīga, Putnu iela ...| 1058|114006186|        0|100003003|0010000|               NULL|
# |40003704886|LV60ZZZ40003704886|"SIA ""KNOW HOUSE"""|                 SIA|          KNOW HOUSE|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2004-10-13|      NULL|      |Rīga, Elizabetes ...| 1050|111633976|        0|100003003|0010000|               NULL|
# |40203101571|LV55ZZZ40203101571|"SIA ""Developmen...|                 SIA|Development Servi...|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2017-10-26|      NULL|      |Liepāja, Mežu iel...| 3405|115989096|        0|100003044|0170000|               NULL|
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# only showing top 20 rows

# %%
# Write DataFrame to Delta table
df.write.format("delta").mode("overwrite").save(delta_table_path)

# Stop the Spark session
spark.stop()
# Out:
# 24/01/17 15:35:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/01/17 15:35:30 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %% [markdown]
# # Processing

# %% [markdown]
# Processing these step before writing data to layer silver
# 1. Transform to standard schema of layer silver
# 2. Unique each record
# 3. Add fields
# 4. Map entities
# 5. Upsert

# %% [markdown]
# Read delta table and discovery data

# %%
# Create a Spark session
spark = SparkSession.builder \
    .appName("CsvToDelta") \
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.0.0,org.apache.hadoop:hadoop-aws:3.3.1") \
    .config("spark.hadoop.fs.s3a.endpoint", obj_storage_endpoint) \
    .config("spark.hadoop.fs.s3a.access.key", obj_storage_access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", obj_storage_secret_key) \
    .config('spark.hadoop.fs.s3a.path.style.access', "true") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()
# Out:
# 24/01/17 15:38:40 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
delta_table_path = "s3a://warehouse/bronze/latvia_entities.delta"

# %%
# Read Delta table
df = spark.read.format("delta").load(delta_table_path)

# %%
df.show()
# Out:
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# |    regcode|              sepa|                name|  name_before_quotes|      name_in_quotes|name_after_quotes|without_quotes|regtype|        regtype_text|type|           type_text|registered|terminated|closed|             address|index|addressid|   region|     city|   atvk|reregistration_term|
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# |40103922165|LV34ZZZ40103922165|"Sabiedrība ar ie...|Sabiedrība ar ier...|             Regalia|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2015-08-17|2017-01-05|     L|Rīga, Čiekurkalna...| 1026|112738842|        0|100003003|0010000|               NULL|
# |40008313326|LV94ZZZ40008313326|"""DUBULTI. DIZAI...|                NULL|    DUBULTI. DIZAINS|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2022-01-28|      NULL|      |Jūrmala, Viestura...| 2010|106310518|        0|100003036|   NULL|               NULL|
# |40008291476|LV90ZZZ40008291476| """Zelta rīti 24"""|                NULL|       Zelta rīti 24|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2019-10-08|      NULL|      |Mārupes nov., Mār...| 2167|117611128|100016583|100003815|0807600|               NULL|
# |43602003030|LV43ZZZ43602003030|"J.Lavrinoviča in...|J.Lavrinoviča ind...|              L.P.K.|             NULL|             0|      U|Uzņēmumu reģistra...| IND|Individuālais uzņ...|1994-03-25|      NULL|      |Jelgavas nov., Gl...| 3040|115799541|100015895|        0|0545200|               NULL|
# |40008313330|LV83ZZZ40008313330|"Biedrība ""MIHAI...|            Biedrība|       MIHAILOVSKOJE|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2022-01-28|      NULL|      |Rīga, Mazā Rencēn...| 1073|105753318|        0|100003003|   NULL|               NULL|
# |40003189332|              NULL|"SIA ""Valkas sli...|                 SIA|     Valkas slimnīca|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|1994-04-06|2008-01-02|     R|Valkas rajons, Va...| 4701|101186812|        0|100003696|0940100|               NULL|
# |40003189559|              NULL|"Sabiedrība ar ie...|Sabiedrība ar ier...|              MISKAM|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|1994-04-07|2009-02-26|     L|Rīga, Aleksandra ...| 1011|101108482|        0|100003003|0010000|               NULL|
# |40003190793|              NULL|"""RĪGAS KREMATOR...|                NULL|   RĪGAS KREMATORIJA|              SIA|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|1994-04-14|2009-11-05|     L| Rīga, Varoņu iela 3| 1005|105113956|        0|100003003|0010000|               NULL|
# |40103239254|LV95ZZZ40103239254|"SIA ""G & P Toba...|                 SIA|       G & P Tobacco|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2009-07-16|      NULL|      |Rīga, Artilērijas...| 1001|111150972|        0|100003003|   NULL|               NULL|
# |50103433471|LV91ZZZ50103433471|"SIA ""Muller Glo...|                 SIA| Muller Global Steel|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2011-07-04|2018-05-10|     L|Rīga, Ģertrūdes i...| 1009|111243306|        0|100003003|0010000|               NULL|
# |40103543252|LV95ZZZ40103543252|"Sabiedrība ar ie...|Sabiedrība ar ier...|Accounting Manage...|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2012-05-10|2021-01-28|     L|Rīga, Dzelzavas i...| 1084|111552441|        0|100003003|0010000|               NULL|
# |40203355364|LV15ZZZ40203355364|       SIA Gribzavod|                 SIA|           Gribzavod|             NULL|             1|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2021-10-25|2023-06-28|     L|Rīga, Matīsa iela...| 1009|112265456|        0|100003003|   NULL|               NULL|
# |51203063711|LV79ZZZ51203063711|     "SIA ""Bisan"""|                 SIA|               Bisan|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2018-06-11|2021-01-28|     L|Kuldīgas nov., Ku...| 3301|102221420|100015942|100003286|0620201|               NULL|
# |40008197393|LV95ZZZ40008197393|"Sporta klubs ""D...|        Sporta klubs|        DAUGAVA 2012|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2012-07-19|      NULL|      |Ķekavas nov., Ķek...| 2123|117702423|100016470|100003831|0800870|               NULL|
# |40002173480|LV26ZZZ40002173480|           IK Ania G|                  IK|              Ania G|             NULL|             1|      K|      Komercreģistrs|  IK|Individuālais kom...|2014-12-15|2023-05-09|     L|Augšdaugavas nov....| 5463|115818734|100016462|        0|0440276|               NULL|
# |40008115185|LV60ZZZ40008115185|     """Tirgus 31"""|                NULL|           Tirgus 31|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2007-05-15|      NULL|      |Liepāja, Tirgus i...| 3401|117299553|        0|100003044|0170000|               NULL|
# |50008136371|LV82ZZZ50008136371|"""Latvijas Lietu...|                NULL|Latvijas Lietuvie...|             NULL|             0|      B|Biedrību un nodib...| BDR|            Biedrība|2009-02-09|      NULL|      |Rīga, Purva iela ...| 1083|111660962|        0|100003003|   NULL|               NULL|
# |40203265107|LV23ZZZ40203265107|   "SIA ""RDV Car"""|                 SIA|             RDV Car|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2020-10-06|2023-06-28|     L|Rīga, Maskavas ie...| 1063|112440640|        0|100003003|   NULL|               NULL|
# |40103162851|              NULL|"Sabiedrība ar ie...|Sabiedrība ar ier...|            FestTime|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2008-04-10|2013-07-29|     L|Rīga, Mazā Krasta...| 1003|100003003|        0|100003003|0010000|               NULL|
# |43603050812|LV76ZZZ43603050812|"Sabiedrība ar ie...|Sabiedrība ar ier...|             Grats G|             NULL|             0|      K|      Komercreģistrs| SIA|Sabiedrība ar ier...|2011-12-06|      NULL|      |Jelgava, Pavasara...| 3001|102504764|        0|100003028|0090000|               NULL|
# +-----------+------------------+--------------------+--------------------+--------------------+-----------------+--------------+-------+--------------------+----+--------------------+----------+----------+------+--------------------+-----+---------+---------+---------+-------+-------------------+
# only showing top 20 rows
